# %% [markdown]
# <a href="https://colab.research.google.com/github/PLUXINDUI/Ispm_course/blob/main/%D0%A3%D0%9F%D0%98%D0%A1_%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%E2%84%962_%D0%A4%D0%BE%D1%80%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5_%D0%B8%D0%B5%D1%80%D0%B0%D1%80%D1%85%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%BE%D0%B9_%D1%81%D1%82%D1%80%D1%83%D0%BA%D1%82%D1%83%D1%80%D1%8B_%D0%BF%D1%80%D0%BE%D0%B5%D0%BA%D1%82%D0%B0_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Задание 2. Формирование иерархической структуры проекта в контексте управления проектами информационных систем**

# %% [markdown]
# Разработка десктопного приложения на основе нейросетевой модели для симуляции влияния аэродинамических модификаций кузова автомобиля на его скоростные характеристики.

# %% [markdown]
# ## **Введение**

# %% [markdown]
#  **Структурированное планирование является фундаментальным навыком проектного менеджера**. Создание иерархической структуры работ (WBS - Work Breakdown Structure) - это один из основных инструментов управления проектами, который позволяет декомпозировать крупные задачи на управляемые компоненты.

# %% [markdown]
# ## **Формулировка задания**

# %% [markdown]
# На основе ваших ответов на предыдущие вопросы о цели, задачах и практической значимости проекта ([Задание №1](https://colab.research.google.com/drive/12wuBTgZlyS8ZYLXjw2SQ2F-wHGbBU0nC?usp=sharing)), сформулируйте его детальную структуру, следуя приведенному шаблону:
#
# 1. Структура должна содержать **минимум** 3 раздела первого уровня (главы)
# 2. Каждый раздел первого уровня должен содержать **минимум** 3 подраздела второго уровня (параграфы)
# 3. Каждый подраздел второго уровня должен содержать **минимум** 3 подраздела третьего уровня (подпараграфы)
#
# Для каждого элемента структуры предоставьте краткое описание содержания (1-2 предложения), которое поясняет, что будет рассмотрено в данном разделе и как это соотносится с общей целью и задачами работы.

# %% [markdown]
# ### **Шаблон структуры с примерным* содержанием**

# %% [markdown]
# * **Примерным, это не значит, что нужно сделать один-в-один!**

# %% [markdown]
# ## **ТРЕБОВАНИЯ К ВЫПОЛНЕНИЮ**

# %% [markdown]
# 1. **Конкретизируйте наименования разделов в соответствии с Вашей темой** — измените названия структурных элементов всех уровней (глав, параграфов, подпараграфов) таким образом, чтобы они точно отражали специфику Вашего проекта. При этом **сохраняйте общую логику структуры**: **в первой главе представляется теоретическое обоснование и обзор имеющихся решений, во второй проводится аналитическая работа и формирование требований, в третьей предлагается и оценивается Ваше решение.**
#
# 2. **Обеспечьте логическую последовательность изложения материала** — содержание работы должно развиваться в направлении - от теоретических основ к практическим аспектам, от обзора предметной области к анализу, от анализа к созданию своего обоснованного решения и его оценке.
#
# 3. **Сопоставьте структуру с целью и задачами работы** — каждый структурный раздел должен соответствовать решению одной или нескольких поставленных задач, способствуя тем самым достижению основной цели проекта.
#
# 4. **Интегрируйте ранее сформулированные положения** — при разработке структуры и содержания разделов опирайтесь на ранее определенные формулировки цели, задач и практической значимости работы, обеспечивая тем самым внутреннюю согласованность проекта.

# %% [markdown]
# <font color='red'><b>↓ ↓ ↓ Ваш ответ ↓ ↓ ↓</b></font>

# %% [markdown]
# ```
# 1. ТЕОРЕТИЧЕСКИЕ ОСНОВЫ И АНАЛИЗ ПРЕДМЕТНОЙ ОБЛАСТИ
#    1.1. Принципы автомобильной аэродинамики и их влияние на скоростные характеристики
#       1.1.1. Основные аэродинамические коэффициенты и их физический смысл. Объясняется, что такое лобовое сопротивление и
#       прижимная сила, как они измеряются и почему критичны для проектирования автомобилей.
#       1.1.2. Влияние аэродинамических модификаций на динамику автомобиля. Анализируется, как спойлеры, диффузоры,
#       обвесы изменяют поток воздуха и, как следствие,
#       характеристики движения — на основе данных из технической литературы и исследований SAE.
#       1.1.3. Роль аэродинамики в инженерной подготовке студентов. Обосновывается необходимость наглядных инструментов для обучения, особенно в условиях ограниченного доступа к CFD-системам и аэродинамическим трубам.
#    1.2. Обзор существующих решений и технологий
#       1.2.1. Профессиональные CFD-системы: возможности и ограничения. Показано, почему такие инструменты непригодны для массового обучения студентов (сложность, стоимость, ресурсоёмкость).
#       1.2.2. Учебные и демонстрационные приложения. Рассматриваются существующие образовательные симуляторы, их функционал и недостатки (статичность, отсутствие интерактивности, упрощённая физика).
#       1.2.3. Подходы на основе машинного обучения в аэродинамике. Обзор современных исследований, где нейросети используются для быстрой оценки аэродинамических характеристик (включая DrivAerML и аналоги).
#    1.3. Технологический стек для разработки интерактивного симулятора
#       1.3.1. Возможности Python в научных вычислениях и ML. Роль библиотек scikit-learn, TensorFlow, PyTorch в создании быстрых предиктивных моделей.
#       1.3.2. Инструменты 3D-визуализации и GUI. Сравнение PyQt6, PyVista, Open3D, VTK — выбор в пользу связки PyQt6 + PyVista для баланса между производительностью и простотой.
#       1.3.3. Упаковка и распространение приложения. Использование PyInstaller для создания автономного .exe-файла, пригодного для установки в компьютерных классах.
# 2. ФОРМИРОВАНИЕ ТРЕБОВАНИЙ И КОНЦЕПЦИИ РЕШЕНИЯ
#    2.1. Анализ потребностей целевой аудитории
#       2.1.1. Типичные учебные задачи студентов-практикантов. Примеры заданий, где требуется оценить влияние модификаций на аэродинамику.
#       2.1.2. Ограничения текущих методов обучения. Отсутствие интерактивности, необходимость ручных расчётов, сложность визуализации потоков.
#       2.1.3. Ожидания от интерактивного симулятора. Быстрый отклик, наглядность, возможность «поиграть» с параметрами, получить численный и визуальный результат.
#
#    2.2. Формирование функциональных и нефункциональных требований
#       2.2.1. Функциональные требования. Выбор автомобиля, добавление/удаление элементов, расчёт Cx/Cl, пересчёт скоростных характеристик, 3D-визуализация потоков, экспорт отчёта.
#       2.2.2. Нефункциональные требования. Работа без интернета, запуск на обычном ноутбуке, время отклика < 0.5 сек, простота интерфейса.
#       2.2.3. Сценарии взаимодействия пользователя. Диаграммы использования: «Студент оценивает влияние спойлера», «Сравнение двух конфигураций» и т.п.
#
#    2.3. Архитектура и методология разработки решения
#       2.3.1. Выбор нейросетевой модели вместо CFD. Обоснование компромисса: скорость vs. точность — приемлемо для учебных целей.
#       2.3.2. Источники данных для обучения модели. Использование открытого датасета DrivAerML и дополнение эмпирическими зависимостями из литературы.
#       2.3.3. Модульная архитектура приложения. Разделение на: ядро (расчёт), БД (авто + элементы), визуализатор, GUI — для гибкости и расширяемости.
#
# 3. РЕАЛИЗАЦИЯ, ТЕСТИРОВАНИЕ И ОЦЕНКА РЕЗУЛЬТАТОВ
#    3.1. Программная реализация приложения
#       3.1.1. Разработка базы данных моделей и элементов. Хранение в JSON/SQLite: структура записей, параметризация элементов (угол, размер и т.д.).
#       3.1.2. Обучение и интеграция нейросетевой модели. Подготовка данных, обучение MLP, сохранение модели, интеграция в PyQt-приложение через joblib.
#       3.1.3. Реализация 3D-визуализатора с ламинарными потоками. Использование PyVista для отображения модели и синтетических линий тока, имитирующих обтекание.
#
#    3.2. Апробация и верификация результатов
#       3.2.1. Тестирование точности предсказаний модели. Сравнение с данными DrivAerML: MAE для C x < 0.005.
#       3.2.2. Тестирование использования
#       3.2.3. Оценка соответствия исходным требованиям. Проверка, решает ли приложение поставленные задачи.
#
#    3.3. Практическая значимость и перспективы развития
#       3.3.1. Возможности внедрения в учебный процесс НАМИ
#       3.3.2. Польза для студентов и преподавателей
#       3.3.3. Направления дальнейшего развития
# ```
