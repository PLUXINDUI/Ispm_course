# %% [markdown]
# <a href="https://colab.research.google.com/github/PLUXINDUI/Ispm_course/blob/main/%22%D0%A3%D0%9F%D0%98%D0%A1_%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5_%E2%84%961_%D0%9E%D0%BF%D1%80%D0%B5%D0%B4%D0%B5%D0%BB%D0%B5%D0%BD%D0%B8%D0%B5_%D0%BA%D0%BE%D0%BD%D1%86%D0%B5%D0%BF%D1%82%D1%83%D0%B0%D0%BB%D1%8C%D0%BD%D1%8B%D1%85_%D0%BE%D1%81%D0%BD%D0%BE%D0%B2_%D0%B4%D0%B8%D0%BF%D0%BB%D0%BE%D0%BC%D0%BD%D0%BE%D0%B3%D0%BE_%D0%BF%D1%80%D0%BE%D0%B5%D0%BA%D1%82%D0%B0_%D0%B2_%D0%BE%D0%B1%D0%BB%D0%B0%D1%81%D1%82%D0%B8_%D0%B8%D0%BD%D1%84%D0%BE%D1%80%D0%BC%D0%B0%D1%86%D0%B8%D0%BE%D0%BD%D0%BD%D1%8B%D1%85_%D1%81%D0%B8%D1%81%D1%82%D0%B5%D0%BC_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Задание 1. Определение концептуальных основ дипломного проекта в области информационных систем**

# %% [markdown]
# Разработка десктопного приложения на основе нейросетевой модели для симуляции влияния аэродинамических модификаций кузова автомобиля на его скоростные характеристики.

# %% [markdown]
# #### **1. Обоснование необходимости разработки**

# %% [markdown]
# Для кого предназначено разрабатываемое Вами решение и какие потребности целевой аудитории оно призвано удовлетворить?

# %% [markdown]
# *Обоснуйте актуальность решаемой проблемы для конкретных заинтересованных сторон.*

# %% [markdown]
# <font color='red'><b>Ваш ответ</b></font>

# %% [markdown]
# Приложение разрабатывается в первую очередь для студентов-практикантов, проходящих обучение в НАМИ.
#
# Но у них нет времени и доступа, чтобы сразу погружаться в сложные CFD-пакеты или проводить натурные испытания в аэродинамической трубе. Им нужно быстро, наглядно и понятно увидеть связь между формой и физикой.
#
# Именно это и даёт наше приложение:
# — интерактивный симулятор, где можно «собрать» автомобиль, «надеть» аэродинамические элементы и сразу увидеть результат — и численно (коэффициенты, скорость), и визуально (как течёт воздух).
#
# Кроме того, приложение будет полезно широкой аудитории — автолюбителям, школьникам, студентам других вузов, которые хотят понять, как работает аэродинамика на реальных примерах, а не только по формулам. Это своего рода «мост» между теорией и инженерной практикой.

# %% [markdown]
# ---

# %% [markdown]
# #### **2. Ожидаемые результаты проекта**

# %% [markdown]
# Опишите конкретные результаты, которые планируется получить по завершении проекта. Какой программный продукт, методика или информационная система будет создан/создана в результате вашей работы?

# %% [markdown]
# <font color='red'><b>Ваш ответ</b></font>

# %% [markdown]
# Будет разработано готовое к использованию десктопное приложение на Python, которое можно установить на любой компьютер в лаборатории НАМИ или запустить дома.
#
# Внутри оно объединяет:
#
# Базу моделей автомобилей — включая как типовые учебные примеры (упрощённые кузова вроде DrivAer).
# Каталог аэродинамических элементов — спойлеры, диффузоры, боковые юбки — с возможностью настраивать угол, размер, положение.
# Нейросетевую модель, обученную на открытых CFD-данных (DrivAerML) и дополненную эмпирическими зависимостями из справочников (например, Hoerner). Она мгновенно оценивает, как выбранные модификации повлияют на C
# x
# ​
#   и прижимную силу.
# Модуль расчёта скоростных характеристик: на основе полученного C
# x
# ​
#   , мощности двигателя и массы машины приложение рассчитывает новую максимальную скорость и динамику разгона.
# 3D-визуализатор с упрощёнными, но правдоподобными линиями ламинарного потока вокруг кузова — чтобы студент видел, а не просто читал.

# %% [markdown]
# ---

# %% [markdown]
# #### **3. Методология использования**

# %% [markdown]
# Каким образом предполагается практическое применение разрабатываемого решения? Опишите основные сценарии взаимодействия пользователей с разрабатываемым решением.

# %% [markdown]
# Представьте типичную неделю практики в НАМИ:
# Студенты приходят на занятие по аэродинамике. Вместо того чтобы час слушать лекцию о коэффициенте C
# x
# ​
#   , им дают задание:
#
# «Возьмите базовую модель, добейтесь снижения лобового сопротивления хотя бы на 5% за счёт внешних модификаций».
#
# Они запускают приложение:
#
# Выбирают автомобиль (например, упрощённый седан),
# Добавляют закрытую решётку радиатора → C
# x
# ​
#   падает на 0.02,
# Устанавливают спойлер под углом 10° → прижим растёт, но C
# x
# ​
#   немного растёт,
# Пробуют диффузор → поток сзади «прилипает» лучше, C
# x
# ​
#   снова падает.
# Всё это происходит в реальном времени, с визуальной обратной связью.

# %% [markdown]
# #### **4. Входные данные и их источники**

# %% [markdown]
# Какие типы данных будут использоваться в качестве входных данных для вашего решения? В каком формате они будут представлены и из каких источников планируется их получение?

# %% [markdown]
# <font color='red'><b>Ваш ответ</b></font>

# %% [markdown]
# Геометрии и аэродинамические коэффициенты — из открытого научного датасета DrivAerML (https://caemldatasets.org/drivaerml/ ), разработанного для машинного обучения в аэродинамике. Это данные, полученные в результате полноценных CFD-расчётов при реалистичных условиях.
# Характеристики реальных автомобилей (мощность, масса, базовый C
# x
# ​
#   ) — из официальных технических спецификаций, а также из внутренних учебных материалов НАМИ (без раскрытия закрытых данных).
# Влияние аэродинамических элементов — на основе классических справочников
#  и публикаций SAE, где указано, как угол спойлера или высота диффузора влияют на коэффициенты.

# %% [markdown]
# ---

# %% [markdown]
# #### **5. Выходные данные и практическая значимость**

# %% [markdown]
# Какие результаты будет формировать Ваше решение на выходе?

# %% [markdown]
# <font color='red'><b>Ваш ответ</b></font>

# %% [markdown]
# Мгновенную оценку влияния любой модификации на аэродинамику и динамику автомобиля,
#
# Наглядную 3D-визуализацию обтекания — чтобы понять, почему что-то работает

# %% [markdown]
# ---

# %% [markdown]
# Опишите конкретно и без "воды" пользу (практическую ценность), которую заинтересованные стороны получат от использования этих результатов.

# %% [markdown]
# <font color='red'><b>Ваш ответ</b></font>

# %% [markdown]
# Польза для НАМИ:
#
# Появляется современный, интерактивный инструмент для обучения практикантов,
# Снижается нагрузка на сотрудников — студенты могут экспериментировать самостоятельно,
# Укрепляется репутация института как центра инновационного инженерного образования.
# Польза для студента:
#
# Получает навыки работы с ML-моделями в инженерии — что крайне востребовано в современном автопроме.
# Польза для общества:
#
# Приложение может быть выложено в открытый доступ — и тогда любой школьник или автолюбитель сможет понять, как устроена аэродинамика его машины.

# %% [markdown]
# ---
